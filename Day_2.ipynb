# %% [markdown]
# <a href="https://colab.research.google.com/github/harshitschooled/titanic-data-analysis/blob/main/Day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/preprocessing_practice_dataset.csv")

# %%
df.head()
# Out:
#    Employee_ID   Age  Gender Department  Education  Experience_Years  \
# 0         1001  59.0    Male         HR    Masters                18
# 1         1002  49.0  Female  Marketing  Bachelors                16
# 2         1003  35.0  Female         HR        NaN                19
# 3         1004  28.0  Female         HR        PhD                 9
# 4         1005  41.0    Male         IT  Bachelors                 5
#
#    Monthly_Salary  Performance_Rating        City Attrition
# 0         52350.0                   5     Calicut        No
# 1        118008.0                   2     Chennai       Yes
# 2        119297.0                   1       Kochi       Yes
# 3         50351.0                   2  Trivandrum       Yes
# 4        113668.0                   3  Trivandrum       Yes

# %%
df.tail()
# Out:
#     Employee_ID   Age  Gender Department Education  Experience_Years  \
# 95         1096  54.0  Female         HR   Masters                11
# 96         1097  53.0    Male  Marketing   Masters                13
# 97         1098  43.0    Male        NaN       PhD                 1
# 98         1099  44.0  Female  Marketing       PhD                18
# 99         1100  57.0  Female        NaN       NaN                17
#
#     Monthly_Salary  Performance_Rating        City Attrition
# 95         48625.0                   5     Chennai       Yes
# 96        107873.0                   5  Trivandrum       Yes
# 97         97592.0                   3     Chennai        No
# 98        102052.0                   5     Calicut       Yes
# 99         69261.0                   2     Calicut        No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Employee_ID         100 non-null    int64
#  1   Age                 90 non-null     float64
#  2   Gender              100 non-null    object
#  3   Department          90 non-null     object
#  4   Education           90 non-null     object
#  5   Experience_Years    100 non-null    int64
#  6   Monthly_Salary      90 non-null     float64
#  7   Performance_Rating  100 non-null    int64
#  8   City                90 non-null     object
#  9   Attrition           100 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#        Employee_ID        Age  Experience_Years  Monthly_Salary  \
# count   100.000000  90.000000        100.000000       90.000000
# mean   1050.500000  39.866667          9.360000    75111.988889
# std      29.011492  11.015005          6.210971    28068.924984
# min    1001.000000  21.000000          0.000000    25412.000000
# 25%    1025.750000  29.250000          4.000000    50536.250000
# 50%    1050.500000  41.000000         10.000000    72715.500000
# 75%    1075.250000  48.000000         15.000000    99079.000000
# max    1100.000000  59.000000         19.000000   119297.000000
#
#        Performance_Rating
# count          100.000000
# mean             3.230000
# std              1.476106
# min              1.000000
# 25%              2.000000
# 50%              4.000000
# 75%              5.000000
# max              5.000000

# %%
df.shape
# Out:
# (100, 10)

# %%
df.isnull()
# Out:
#     Employee_ID    Age  Gender  Department  Education  Experience_Years  \
# 0         False  False   False       False      False             False
# 1         False  False   False       False      False             False
# 2         False  False   False       False       True             False
# 3         False  False   False       False      False             False
# 4         False  False   False       False      False             False
# ..          ...    ...     ...         ...        ...               ...
# 95        False  False   False       False      False             False
# 96        False  False   False       False      False             False
# 97        False  False   False        True      False             False
# 98        False  False   False       False      False             False
# 99        False  False   False        True       True             False
#
#     Monthly_Salary  Performance_Rating   City  Attrition
# ...

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10,6))
department_counts = df['Department'].value_counts()
colors = sns.color_palette('pastel')[0:len(department_counts)]
plt.pie(department_counts, labels=department_counts.index, autopct='%1.1f%%', startangle=90, colors=colors)
plt.title('Distribution of Departments')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
df["Department_mode_imputed"]=df["Department"].fillna(df["Department"].mode()[0])

# %%
df[['Age','Age_mean_imputed','Age_median_imputed','Department',"Department_mode_imputed"]]
# Out:
#      Age  Age_mean_imputed  Age_median_imputed Department  \
# 0   59.0              59.0                59.0         HR
# 1   49.0              49.0                49.0  Marketing
# 2   35.0              35.0                35.0         HR
# 3   28.0              28.0                28.0         HR
# 4   41.0              41.0                41.0         IT
# ..   ...               ...                 ...        ...
# 95  54.0              54.0                54.0         HR
# 96  53.0              53.0                53.0  Marketing
# 97  43.0              43.0                43.0        NaN
# 98  44.0              44.0                44.0  Marketing
# 99  57.0              57.0                57.0        NaN
#
#    Department_mode_imputed
# 0                       HR
# 1                Marketing
# 2                       HR
# 3                       HR
# 4                       IT
# ..                     ...
# 95                      HR
# 96               Marketing
# ...

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10,6))
sns.histplot(data=df,x='Employee_ID',y='Department',palette='pastel')
plt.title('Boxplot of Department by Employee id')
plt.xlabel('Employee id')
plt.ylabel('Department')
# Out:
# /tmp/ipykernel_407/871866371.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df,x='Employee_ID',y='Department',palette='pastel')
# Text(0, 0.5, 'Department')

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=df,x='Department',y='Monthly_Salary',palette='pastel')
plt.title('Barplot of Monthly_Salary by department',fontsize=16)
plt.xlabel('Department',fontsize=12)
plt.ylabel('Monthly_Salary',fontsize=12)
# Out:
# /tmp/ipykernel_407/2741643427.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df,x='Department',y='Monthly_Salary',palette='pastel')
# Text(0, 0.5, 'Monthly_Salary')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Department', y='Employee_ID', hue='Experience_Years', palette='pastel', legend=False)

plt.title('Boxplot of Departments by Department',fontsize=16)
plt.xlabel('Department',fontsize=12)
plt.ylabel('Departments',fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_407/3030790364.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='Department',y='Employee_ID',palette='pastel')
# Text(0, 0.5, 'EmployeeID')

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10,6))
sns.boxplot(data=df,x='Employee_ID',y='Department',palette='pastel')
plt.title('Boxplot of Department by Employee id')
plt.xlabel('Employee id')
plt.ylabel('Department')
# Out:
# /tmp/ipykernel_407/743625211.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='Employee_ID',y='Department',palette='pastel')
# Text(0, 0.5, 'Department')

# %%
from sklearn.preprocessing import LabelEncoder

# Add label encoding for Department to encoded_data
department_label_encoder = LabelEncoder()
encoded_data['Department_Label_Encoded'] = department_label_encoder.fit_transform(encoded_data['Department'].astype(str))

# %%
label_encoder=LabelEncoder()
df['Gender_Label_Encoded']=label_encoder.fit_transform(df['Gender'])

# %%
# Initialize encoded_data as a copy of df to avoid modifying the original DataFrame.
encoded_data = df.copy()

# Apply label encoding for 'Gender'
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
encoded_data['Gender_Label'] = label_encoder.fit_transform(encoded_data['Gender'])

# Perform one-hot encoding for 'Department'
one_hot_encoded = pd.get_dummies(encoded_data['Department'], prefix='Department')
encoded_data = pd.concat([encoded_data, one_hot_encoded], axis=1)

print(encoded_data[['Gender', 'Gender_Label', 'Department', 'Department_HR', 'Department_Marketing', 'Department_IT', 'Department_Sales', 'Department_Finance']].head())
# Out:
#    Gender  Gender_Label Department  Department_HR  Department_Marketing  \
# 0    Male             1         HR           True                 False
# 1  Female             0  Marketing          False                  True
# 2  Female             0         HR           True                 False
# 3  Female             0         HR           True                 False
# 4    Male             1         IT          False                 False
#
#    Department_IT  Department_Sales  Department_Finance
# 0          False             False               False
# 1          False             False               False
# 2          False             False               False
# 3          False             False               False
# 4           True             False               False

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

numerical_col=['Age','Experience_Years','Monthly_Salary']

# Drop rows with NaN values in numerical columns and reset index for clean assignment
df.dropna(subset=numerical_col,inplace=True)
df.reset_index(drop=True, inplace=True)

minmax_scaler=MinMaxScaler()
standard_scaler=StandardScaler()

# Apply Min-Max Scaling and Standard Scaling to 'Age'
df['Age_MinMax']=minmax_scaler.fit_transform(df[['Age']])
df['Age_Standard']=standard_scaler.fit_transform(df[['Age']])

# Apply Min-Max Scaling and Standard Scaling to 'Experience_Years'
df['Experience_Years_MinMax']=minmax_scaler.fit_transform(df[['Experience_Years']])
df['Experience_Years_Standard']=standard_scaler.fit_transform(df[['Experience_Years']])

# Apply Min-Max Scaling and Standard Scaling to 'Monthly_Salary'
df['Monthly_Salary_MinMax']=minmax_scaler.fit_transform(df[['Monthly_Salary']])
df['Monthly_Salary_Standard']=standard_scaler.fit_transform(df[['Monthly_Salary']])

# Print columns to verify creation of scaled columns
print("DataFrame columns after scaling:")
print(df.columns)
# Out:
# DataFrame columns after scaling:
# Index(['Employee_ID', 'Age', 'Gender', 'Department', 'Education',
#        'Experience_Years', 'Monthly_Salary', 'Performance_Rating', 'City',
#        'Attrition', 'Age_mean_imputed', 'Age_median_imputed',
#        'Department_mode_imputed', 'Monthly_Salary_mean_imputed',
#        'Gender_Label_Encoded', 'Age_MinMax', 'Age_Standard',
#        'Experience_Years_MinMax', 'Experience_Years_Standard',
#        'Monthly_Salary_MinMax', 'Monthly_Salary_Standard'],
#       dtype='object')
