# %% [markdown]
# <a href="https://colab.research.google.com/github/harshitschooled/AI-ML-Internship/blob/main/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

print(os.listdir('/content'))
# Out:
# ['.config', 'Dataset.zip', 'sample_data']

# %%
import os

print("Size:", os.path.getsize("/content/Dataset.zip"), "bytes")
# Out:
# Size: 232783872 bytes

# %%
# !file /content/Dataset.zip
# Out:
# /content/Dataset.zip: Zip archive data, at least v4.5 to extract, compression method=deflate

# %%
import zipfile

with zipfile.ZipFile('/content/Dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/Dataset')

print("Extraction completed!")
# Out:
# Extraction completed!

# %%
import os

print(os.listdir('/content/Dataset')[:10])
# Out:
# ['flowers']

# %%
import os

dataset_path = "/content/Dataset/flowers"

images = []

for file in os.listdir(dataset_path):
    if file.lower().endswith(('.jpg', '.jpeg', '.png')):
        images.append(file)

print("Total images:", len(images))
# Out:
# Total images: 0

# %%
import os

print(os.listdir('/content/Dataset/flowers'))
# Out:
# ['daisy', 'dandelion', 'rose', 'tulip', 'sunflower']

# %%
import os

dataset_path = "/content/Dataset/flowers"

count = 0

for root, dirs, files in os.walk(dataset_path):
    for file in files:
        if file.lower().endswith(('.jpg', '.jpeg', '.png')):
            count += 1

print("Total images:", count)
# Out:
# Total images: 4317

# %%
print(os.listdir('/content/Dataset/flowers'))
# Out:
# ['daisy', 'dandelion', 'rose', 'tulip', 'sunflower']

# %%
import os
import cv2
import matplotlib.pyplot as plt

dataset_path = "/content/Dataset/flowers"

image_paths = []

for root, dirs, files in os.walk(dataset_path):
    for file in files:
        if file.lower().endswith(('.jpg', '.jpeg', '.png')):
            image_paths.append(os.path.join(root, file))

plt.figure(figsize=(15,5))

for i in range(5):
    img = cv2.imread(image_paths[i])
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    plt.subplot(1,5,i+1)
    plt.imshow(img)
    plt.axis("off")

plt.show()

# %%
import pandas as pd
import cv2
import os

data = []

for path in image_paths[:10]:
    img = cv2.imread(path)

    height, width, channels = img.shape

    data.append([
        os.path.basename(path),
        height,
        width,
        channels
    ])

df = pd.DataFrame(
    data,
    columns=["Image", "Height", "Width", "Channels"]
)

df
# Out:
#                           Image  Height  Width  Channels
# 0   4065883015_4bb6010cb7_n.jpg     240    320         3
# 1  21402054779_759366efb0_n.jpg     240    320         3
# 2  19813618946_93818db7aa_m.jpg     240    227         3
# 3   4511693548_20f9bd2b9c_m.jpg     240    240         3
# 4  34661399476_9ea7e2fd53_n.jpg     159    240         3
# 5    10140303196_b88d3d6cec.jpg     313    500         3
# 6  16161045294_70c76ce846_n.jpg     213    320         3
# 7  11023272144_fce94401f2_m.jpg     240    159         3
# 8  34571214621_f655295459_n.jpg     240    201         3
# 9  34696730126_056ffea63c_n.jpg     240    159         3

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread(image_paths[0])

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

resized = cv2.resize(img_rgb, (224, 224))

print("Original Shape:", img_rgb.shape)
print("Resized Shape:", resized.shape)

plt.figure(figsize=(8,4))

plt.subplot(1,2,1)
plt.imshow(img_rgb)
plt.title("Original")

plt.subplot(1,2,2)
plt.imshow(resized)
plt.title("224x224")

plt.show()
# Out:
# Original Shape: (240, 320, 3)
# Resized Shape: (224, 224, 3)
